# %% [markdown]
# #### 1. Data Visualization and statistical inferences

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/pavla/Downloads/Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.figure()
plt.subplot(2,2,1)
plt.hist(data["SepalWidthCm"])
plt.show()
plt.subplot(2,2,2)
plt.hist(data["SepalLengthCm"])
plt.show()
plt.subplot(2,2,3)
plt.hist(data["PetalLengthCm"])
plt.show()
plt.subplot(2,2,4)
plt.hist(data["PetalWidthCm"])
plt.show()

# %% [markdown]
# #### scatter plots

# %%
sns.histplot(data["PetalWidthCm"],kde=True)
plt.show()

# %%
plt.boxplot(data["SepalLengthCm"])
plt.show()

# %%
plt.boxplot(data["PetalLengthCm"])
plt.show()

# %%
plt.boxplot(data["SepalWidthCm"])
plt.show()

# %%
plt.boxplot(data["PetalWidthCm"])
plt.show()

# %%
plt.pie(data['SepalLengthCm'])
plt.show()

# %%
plt.pie(data['SepalWidthCm'])
plt.show()

# %%
plt.pie(data['PetalLengthCm'])
plt.show()

# %%
plt.pie(data['PetalWidthCm'])
plt.show()

# %%
plt.scatter(data["SepalLengthCm"],data["SepalWidthCm"])
plt.show()

# %%
plt.scatter(data["PetalLengthCm"],data["PetalWidthCm"])
plt.show()

# %%
print(data["SepalLengthCm"].mean())
print(data["SepalWidthCm"].mean())
print(data["PetalLengthCm"].mean())
print(data["PetalWidthCm"].mean())
# Out:
# 5.843333333333334
# 3.0540000000000003
# 3.758666666666666
# 1.1986666666666668

# %%
print(data["SepalLengthCm"].mode())
print(data["SepalWidthCm"].mode())
print(data["PetalLengthCm"].mode())
print(data["PetalWidthCm"].mode())
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64
# 0    3.0
# Name: SepalWidthCm, dtype: float64
# 0    1.5
# Name: PetalLengthCm, dtype: float64
# 0    0.2
# Name: PetalWidthCm, dtype: float64

# %%
print(data["SepalLengthCm"].median())
print(data["SepalWidthCm"].median())
print(data["PetalLengthCm"].median())
print(data["PetalWidthCm"].median())
# Out:
# 5.8
# 3.0
# 4.35
# 1.3

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data[["SepalLengthCm","SepalWidthCm"]].corr()
# Out:
#                SepalLengthCm  SepalWidthCm
# SepalLengthCm       1.000000     -0.109369
# SepalWidthCm       -0.109369      1.000000

# %%
data[["PetalLengthCm","PetalWidthCm"]].corr()
# Out:
#                PetalLengthCm  PetalWidthCm
# PetalLengthCm       1.000000      0.962757
# PetalWidthCm        0.962757      1.000000
